# %% [markdown]
# # importing libraries

# %%
# !pip install pandas
import pandas as pd
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # connection to the database

# %%
#connection to database
import mysql.connector
    
def create_database():

    conn=mysql.connector.connect(host='localhost',user='root',password='suhas1995',database='sk',autocommit=True)

  #cursor defining  
    cur=conn.cursor()
    
  #creating new database
    cur.execute('drop database myfirstdb')
    cur.execute('create database myfirstdb')
  
  #closing default database connection
    conn.close()
    
  #connecting to new database
    conn=mysql.connector.connect(host='localhost',user='root',password='suhas1995',database='myfirstdb',autocommit=True)
    cur=conn.cursor()
    return cur, conn

# %%
def drop_table(cur,conn):
    for query in drop_table_queries:
        cur.execute(query)
        conn.commit()

# %%
def create_table(cur,conn):
    for query in create_table_queries:
        cur.execute(query)
        conn.commit()

# %%
AccountsCountry=pd.read_csv(r"C:\Users\Dell\Desktop\PROJECT SUHAS\PROJECT\archive\Wealth-AccountsCountry.csv")

# %%
AccountsCountry.head()
# Out:
#   Code                  Long Name         Income Group  \
# 0  ALB        Republic of Albania  Upper middle income
# 1  ARG         Argentine Republic  Upper middle income
# 2  ARM        Republic of Armenia  Upper middle income
# 3  AUS  Commonwealth of Australia          High income
# 4  AUT        Republic of Austria          High income
#
#                       Region Lending category Other groups      Currency Unit  \
# 0      Europe & Central Asia             IBRD          NaN       Albanian lek
# 1  Latin America & Caribbean             IBRD          NaN     Argentine peso
# 2      Europe & Central Asia             IBRD          NaN      Armenian dram
# 3        East Asia & Pacific              NaN          NaN  Australian dollar
# 4      Europe & Central Asia              NaN    Euro area               Euro
#
#                             Latest population census  \
# 0                                    2020 (expected)
# 1                                    2020 (expected)
# ...

# %%
AccountsCountry_clean=AccountsCountry[['Code','Long Name','Region','Short Name','Currency Unit']]

# %%
AccountsCountry_clean.head()
# Out:
#   Code                  Long Name                     Region Short Name  \
# 0  ALB        Republic of Albania      Europe & Central Asia    Albania
# 1  ARG         Argentine Republic  Latin America & Caribbean  Argentina
# 2  ARM        Republic of Armenia      Europe & Central Asia    Armenia
# 3  AUS  Commonwealth of Australia        East Asia & Pacific  Australia
# 4  AUT        Republic of Austria      Europe & Central Asia    Austria
#
#        Currency Unit
# 0       Albanian lek
# 1     Argentine peso
# 2      Armenian dram
# 3  Australian dollar
# 4               Euro

# %%
#removing empty rows
AccountsCountry_cleaned=AccountsCountry_clean.dropna()

# %%
AccountsCountry_cleaned1 = AccountsCountry_cleaned.drop_duplicates()

# %%
AccountsCountry_cleaned1
# Out:
#     Code                      Long Name                      Region  \
# 0    ALB            Republic of Albania       Europe & Central Asia
# 1    ARG             Argentine Republic   Latin America & Caribbean
# 2    ARM            Republic of Armenia       Europe & Central Asia
# 3    AUS      Commonwealth of Australia         East Asia & Pacific
# 4    AUT            Republic of Austria       Europe & Central Asia
# ..   ...                            ...                         ...
# 141  VNM  Socialist Republic of Vietnam         East Asia & Pacific
# 142  PSE             West Bank and Gaza  Middle East & North Africa
# 143  YEM              Republic of Yemen  Middle East & North Africa
# 144  ZMB             Republic of Zambia          Sub-Saharan Africa
# 145  ZWE           Republic of Zimbabwe          Sub-Saharan Africa
#
#              Short Name       Currency Unit
# 0               Albania        Albanian lek
# 1             Argentina      Argentine peso
# ...

# %%
AccountData=pd.read_csv(r"C:\Users\Dell\Desktop\PROJECT SUHAS\PROJECT\archive\Wealth-AccountData.csv")

# %%
AccountData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
AccountData.columns
# Out:
# Index(['Country Name', 'Country Code', 'Series Name', 'Series Code',
#        '1995 [YR1995]', '1996 [YR1996]', '1997 [YR1997]', '1998 [YR1998]',
#        '1999 [YR1999]', '2000 [YR2000]', '2001 [YR2001]', '2002 [YR2002]',
#        '2003 [YR2003]', '2004 [YR2004]', '2005 [YR2005]', '2006 [YR2006]',
#        '2007 [YR2007]', '2008 [YR2008]', '2009 [YR2009]', '2010 [YR2010]',
#        '2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
#        '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],
#       dtype='object')

# %%
AccountData=AccountData.drop(['2011 [YR2011]', '2012 [YR2012]', '2013 [YR2013]', '2014 [YR2014]',
       '2015 [YR2015]', '2016 [YR2016]', '2017 [YR2017]', '2018 [YR2018]'],axis=1)

# %%
AccountData.head()
# Out:
#   Country Name Country Code  \
# 0      Albania          ALB
# 1      Albania          ALB
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                  Human capital (constant 2018 US$)       NW.HCA.TO
# 1       Human capital per capita (constant 2018 US$)       NW.HCA.PC
# 2  Human capital per capita, employed female (con...  NW.HCA.FEMP.PC
# 3  Human capital per capita, employed male (const...  NW.HCA.MEMP.PC
# 4  Human capital per capita, female (constant 201...  NW.HCA.FEMA.PC
#
#   1995 [YR1995] 1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999]  \
# 0      4.49E+10      4.34E+10      3.71E+10      3.88E+10      4.22E+10
# 1      14072.79      13708.99       11794.1      12399.48      13573.26
# 2      3468.858      3355.549      2868.997      3013.391      3259.893
# 3      6507.931      6353.737      5466.692      5901.072       6492.73
# ...

# %%
WealthAccountSeries=pd.read_csv(r"C:\Users\Dell\Desktop\PROJECT SUHAS\PROJECT\archive\Wealth-AccountSeries.csv")

# %%
WealthAccountSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
WealthAccountSeries.columns
# Out:
# Index(['Code', 'Indicator Name', 'Long definition', 'Source', 'Topic',
#        'Unit of measure', 'Periodicity', 'Reference period',
#        'Statistical concept and methodology', 'Previous Indicator Code',
#        'Previous Indicator Name'],
#       dtype='object')

# %%
WealthAccountSeries=WealthAccountSeries.drop(['Statistical concept and methodology','Previous Indicator Code',
       'Previous Indicator Name'],axis=1)

# %%
WealthAccountSeries.head()
# Out:
#              Code                                     Indicator Name  \
# 0       NW.HCA.TO                  Human capital (constant 2018 US$)
# 1       NW.HCA.PC       Human capital per capita (constant 2018 US$)
# 2  NW.HCA.FEMP.PC  Human capital per capita, employed female (con...
# 3  NW.HCA.MEMP.PC  Human capital per capita, employed male (const...
# 4  NW.HCA.FEMA.PC  Human capital per capita, female (constant 201...
#
#                                      Long definition  \
# 0  Human capital is computed as the present value...
# 1  Human capital is computed as the present value...
# 2  Human capital is computed as the present value...
# 3  Human capital is computed as the present value...
# 4  Human capital is computed as the present value...
#
#                                               Source          Topic  \
# 0  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# 1  World Bank. 2021. The Changing Wealth of Natio...  Human capital
# ...

# %%
cur,conn =create_database()

# %%
accounts_country_table_create=("""CREATE TABLE IF NOT EXISTS AccountsCountry(
Country_Code VARCHAR(250) PRIMARY KEY,
Long_Name VARCHAR(250),
Region VARCHAR(250),
Short_Name VARCHAR(250),
Currency_unit VARCHAR(250));""")

# %%
cur.execute(accounts_country_table_create)
conn.commit()

# %%
AccountData_table_create=("""CREATE TABLE IF NOT EXISTS AccountData(
Country_Name VARCHAR(250),
Country_Code VARCHAR(250),
Series_Name VARCHAR(250),
Series_Code VARCHAR(250),
YR1995 NUMERIC ,
YR1996 NUMERIC ,
YR1997 NUMERIC ,
YR1998 NUMERIC ,
YR1999 NUMERIC ,
YR2000 NUMERIC ,
YR2001 NUMERIC ,
YR2002 NUMERIC ,
YR2003 NUMERIC ,
YR2004 NUMERIC ,
YR2005 NUMERIC ,
YR2006 NUMERIC ,
YR2007 NUMERIC ,
YR2008 NUMERIC ,
YR2009 NUMERIC ,
YR2010 NUMERIC);""")

# %%
cur.execute(AccountData_table_create)
conn.commit()

# %%
WealthAccountSeries_table_create=("""CREATE TABLE IF NOT EXISTS WealthAccountSeries(
Code VARCHAR(250),
IndicatorName VARCHAR(250),
Longdefinition VARCHAR(5000),
Source VARCHAR(500),
Topic VARCHAR(500),
Unit_of_measure VARCHAR(500),
Periodicity VARCHAR(500),
Reference_period VARCHAR(500));""")

# %%
cur.execute(WealthAccountSeries_table_create)
conn.commit()

# %%
accounts_country_table_insert=("""INSERT INTO Accountscountry(
Country_Code,
Long_Name,
Region,
Short_Name,
Currency_unit)
VALUES(%s, %s, %s, %s, %s)
""")

# %%
for i, row in AccountsCountry_cleaned1.iterrows():
    cur.execute(accounts_country_table_insert,list(row))

# %%
AccountData_table_insert=("""INSERT INTO AccountData(
Country_Name,
Country_Code ,
Series_Name ,
Series_Code ,
YR1995,
YR1996,
YR1997,
YR1998,
YR1999,
YR2000,
YR2001,
YR2002,
YR2003,
YR2004,
YR2005,
YR2006,
YR2007,
YR2008,
YR2009,
YR2010 )
VALUES(%s, %s, %s, %s, %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s);""")

# %%
for i, row in AccountData.iterrows():
    cur.execute(AccountData_table_insert,list(row))

# %%
WealthAccountSeries_table_insert=("""INSERT INTO WealthAccountSeries(
Code ,
IndicatorName ,
Longdefinition ,
Source ,
Topic ,
Unit_of_measure ,
Periodicity,
Reference_period )
VALUES(%s,%s,%s,%s,%s,%s,%s,%s);""")

# %%
for i, row in WealthAccountSeries.iterrows():
    cur.execute(WealthAccountSeries_table_insert,list(row))

# %%
conn.commit()
